# %%
import pandas as pd
import numpy as np

# %%
df_updateddataset = pd.read_csv("Updated_dataset.csv")
df_updateddataset
# Out:
#            Entity Code  Year  Air pollution (total) (deaths per 100,000)  \
# 0     Afghanistan  AFG  1990                                  299.477309
# 1     Afghanistan  AFG  1991                                  291.277967
# 2     Afghanistan  AFG  1992                                  278.963056
# 3     Afghanistan  AFG  1993                                  278.790815
# 4     Afghanistan  AFG  1994                                  287.162923
# ...           ...  ...   ...                                         ...
# 6463     Zimbabwe  ZWE  2013                                  143.850145
# 6464     Zimbabwe  ZWE  2014                                  138.200536
# 6465     Zimbabwe  ZWE  2015                                  132.752553
# 6466     Zimbabwe  ZWE  2016                                  128.692138
# 6467     Zimbabwe  ZWE  2017                                  125.028843
#
#       Indoor air pollution (deaths per 100,000)  \
# ...

# %%
df_updateddataset.columns
# Out:
# Index(['Entity', 'Code', 'Year', 'Air pollution (total) (deaths per 100,000)',
#        'Indoor air pollution (deaths per 100,000)',
#        'Outdoor particulate matter (deaths per 100,000)',
#        'Outdoor ozone pollution (deaths per 100,000)', 'Entity-1', 'Year-1',
#        'Population', 'GDP', 'Urbanization Rate', 'Energy Consumption',
#        'Air Quality Index (AQI)', 'Healthcare Expenditure',
#        'Legislation and Policy Index', 'Country_section', 'Country_states'],
#       dtype='object')

# %%
#As we can observe there are two year columns and entity columns. Checking whether the data in the columns are same. 
print(df_updateddataset['Entity'].equals(df_updateddataset['Entity-1']))
# Out:
# True

# %%
print(df_updateddataset['Year'].equals(df_updateddataset['Year-1']))
# Out:
# True

# %%
#True means the data of the corresponding columns matches. So, removing the duplicate columns Year-1, Entity-1 from the dataframe. 
df_updateddataset.drop(['Entity-1','Year-1'], axis=1, inplace=True)
df_updateddataset.head()
# Out:
#         Entity Code  Year  Air pollution (total) (deaths per 100,000)  \
# 0  Afghanistan  AFG  1990                                  299.477309
# 1  Afghanistan  AFG  1991                                  291.277967
# 2  Afghanistan  AFG  1992                                  278.963056
# 3  Afghanistan  AFG  1993                                  278.790815
# 4  Afghanistan  AFG  1994                                  287.162923
#
#    Indoor air pollution (deaths per 100,000)  \
# 0                                 250.362910
# 1                                 242.575125
# 2                                 232.043878
# 3                                 231.648134
# 4                                 238.837177
#
#    Outdoor particulate matter (deaths per 100,000)  \
# 0                                        46.446589
# 1                                        46.033841
# 2                                        44.243766
# 3                                        44.440148
# ...

# %%
#As the dataset is related to the country and the year. Number of states doesn't contribute for the analysis and the visualization.Hence, removing unwanted columns from the dataframe
df_updateddataset.drop(['Country_section','Country_states'], axis=1, inplace=True)
df_updateddataset.head()
# Out:
#         Entity Code  Year  Air pollution (total) (deaths per 100,000)  \
# 0  Afghanistan  AFG  1990                                  299.477309
# 1  Afghanistan  AFG  1991                                  291.277967
# 2  Afghanistan  AFG  1992                                  278.963056
# 3  Afghanistan  AFG  1993                                  278.790815
# 4  Afghanistan  AFG  1994                                  287.162923
#
#    Indoor air pollution (deaths per 100,000)  \
# 0                                 250.362910
# 1                                 242.575125
# 2                                 232.043878
# 3                                 231.648134
# 4                                 238.837177
#
#    Outdoor particulate matter (deaths per 100,000)  \
# 0                                        46.446589
# 1                                        46.033841
# 2                                        44.243766
# 3                                        44.440148
# ...

# %%
#Checking number of duplicated rows in the dataset 
df_updateddataset.duplicated().sum()
# Out:
# 0

# %%
#Printing column names which contain null values and empty strings rows in the dataframe
empty_nan_columns = df_updateddataset.columns[(df_updateddataset.isnull() | (df_updateddataset == '')).any()].tolist()

print(empty_nan_columns)
# Out:
# ['Code']

# %%
entities_with_empty_code = df_updateddataset[df_updateddataset['Code'].isnull() | (df_updateddataset['Code'] == '')]['Entity']

# Print the 'Entity' names
print(entities_with_empty_code)
# Out:
# 112           Andean Latin America
# 113           Andean Latin America
# 114           Andean Latin America
# 115           Andean Latin America
# 116           Andean Latin America
#                    ...
# 6351    Western Sub-Saharan Africa
# 6352    Western Sub-Saharan Africa
# 6353    Western Sub-Saharan Africa
# 6354    Western Sub-Saharan Africa
# 6355    Western Sub-Saharan Africa
# Name: Entity, Length: 980, dtype: object

# %%
# Displaying the entities of DataFrame for rows where 'Code' is empty or NaN
entities_with_empty_code = df_updateddataset[df_updateddataset['Code'].isnull() | (df_updateddataset['Code'] == '')]['Entity']
distinct_entities = entities_with_empty_code.unique()
print(distinct_entities)
print(len(distinct_entities))
# Out:
# ['Andean Latin America' 'Australasia' 'Caribbean' 'Central Asia'
#  'Central Europe' 'Central Europe, Eastern Europe, and Central Asia'
#  'Central Latin America' 'Central Sub-Saharan Africa' 'East Asia'
#  'Eastern Europe' 'Eastern Sub-Saharan Africa' 'England' 'High SDI'
#  'High-income' 'High-income Asia Pacific' 'High-middle SDI'
#  'Latin America and Caribbean' 'Low SDI' 'Low-middle SDI' 'Middle SDI'
#  'North Africa and Middle East' 'North America' 'Northern Ireland'
#  'Oceania' 'Scotland' 'South Asia' 'Southeast Asia'
#  'Southeast Asia, East Asia, and Oceania' 'Southern Latin America'
#  'Southern Sub-Saharan Africa' 'Sub-Saharan Africa'
#  'Tropical Latin America' 'Wales' 'Western Europe'
#  'Western Sub-Saharan Africa']
# 35

# %%
#There are total 35 entities whose code is empty or null

# %%
#Generating the codes for the entities whose code is empty or null
def code_(entity):
    words = entity.split()
    code = ''.join(word[0] for word in words)
    return code.upper()

entities = ['Andean Latin America', 'Australasia', 'Caribbean', 'Central Asia',
            'Central Europe', 'Central Europe, Eastern Europe, and Central Asia',
            'Central Latin America', 'Central Sub-Saharan Africa', 'East Asia',
            'Eastern Europe', 'Eastern Sub-Saharan Africa', 'England', 'High SDI',
            'High-income', 'High-income Asia Pacific', 'High-middle SDI',
            'Latin America and Caribbean', 'Low SDI', 'Low-middle SDI', 'Middle SDI',
            'North Africa and Middle East', 'North America', 'Northern Ireland',
            'Oceania', 'Scotland', 'South Asia', 'Southeast Asia',
            'Southeast Asia, East Asia, and Oceania', 'Southern Latin America',
            'Southern Sub-Saharan Africa', 'Sub-Saharan Africa',
            'Tropical Latin America', 'Wales', 'Western Europe',
            'Western Sub-Saharan Africa']

entity_codes = {entity: code_(entity) for entity in entities}

for entity, code in entity_codes.items():
    print(f"{entity} - {code}")
# Out:
# Andean Latin America - ALA
# Australasia - A
# Caribbean - C
# Central Asia - CA
# Central Europe - CE
# Central Europe, Eastern Europe, and Central Asia - CEEEACA
# Central Latin America - CLA
# Central Sub-Saharan Africa - CSA
# East Asia - EA
# Eastern Europe - EE
# Eastern Sub-Saharan Africa - ESA
# England - E
# High SDI - HS
# High-income - H
# High-income Asia Pacific - HAP
# High-middle SDI - HS
# Latin America and Caribbean - LAAC
# Low SDI - LS
# Low-middle SDI - LS
# Middle SDI - MS
# North Africa and Middle East - NAAME
# North America - NA
# Northern Ireland - NI
# Oceania - O
# Scotland - S
# South Asia - SA
# Southeast Asia - SA
# Southeast Asia, East Asia, and Oceania - SAEAAO
# Southern Latin America - SLA
# Southern Sub-Saharan Africa - SSA
# Sub-Saharan Africa - SA
# Tropical Latin America - TLA
# Wales - W
# Western Europe - WE
# Western Sub-Saharan Africa - WSA

# %%
#Replacing the empty rows of the code of corresponding entity with the above generated codes
for entity, code in entity_codes.items():
    df_updateddataset.loc[df_updateddataset['Entity'] == entity, 'Code'] = df_updateddataset.loc[df_updateddataset['Entity'] == entity, 'Code'].fillna(code).replace('', code)

df_updateddataset
# Out:
#            Entity Code  Year  Air pollution (total) (deaths per 100,000)  \
# 0     Afghanistan  AFG  1990                                  299.477309
# 1     Afghanistan  AFG  1991                                  291.277967
# 2     Afghanistan  AFG  1992                                  278.963056
# 3     Afghanistan  AFG  1993                                  278.790815
# 4     Afghanistan  AFG  1994                                  287.162923
# ...           ...  ...   ...                                         ...
# 6463     Zimbabwe  ZWE  2013                                  143.850145
# 6464     Zimbabwe  ZWE  2014                                  138.200536
# 6465     Zimbabwe  ZWE  2015                                  132.752553
# 6466     Zimbabwe  ZWE  2016                                  128.692138
# 6467     Zimbabwe  ZWE  2017                                  125.028843
#
#       Indoor air pollution (deaths per 100,000)  \
# ...

# %%
#Checking column names which contain null values and empty strings rows in the dataframe after updating
empty_nan_columns = df_updateddataset.columns[(df_updateddataset.isnull() | (df_updateddataset == '')).any()].tolist()
print(empty_nan_columns)
# Out:
# []

# %%
#Empty list indicates that there are no rows in the columns which contain nan or empty rows.

# %%
#Importing the ccleaned data as csv. Downloading dataframe as CSV
df_updateddataset.to_csv('C:/Users/Checkout/DV_Project/Cleaneddata.csv', index=False)

# %%
#Displaying the downloaded cleaned data in the dataframe
df_cleaneddata = pd.read_csv("Cleaneddata.csv")
df_cleaneddata
# Out:
#            Entity Code  Year  Air pollution (total) (deaths per 100,000)  \
# 0     Afghanistan  AFG  1990                                  299.477309
# 1     Afghanistan  AFG  1991                                  291.277967
# 2     Afghanistan  AFG  1992                                  278.963056
# 3     Afghanistan  AFG  1993                                  278.790815
# 4     Afghanistan  AFG  1994                                  287.162923
# ...           ...  ...   ...                                         ...
# 6463     Zimbabwe  ZWE  2013                                  143.850145
# 6464     Zimbabwe  ZWE  2014                                  138.200536
# 6465     Zimbabwe  ZWE  2015                                  132.752553
# 6466     Zimbabwe  ZWE  2016                                  128.692138
# 6467     Zimbabwe  ZWE  2017                                  125.028843
#
#       Indoor air pollution (deaths per 100,000)  \
# ...

# %%
df_cleaneddata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6468 entries, 0 to 6467
# Data columns (total 14 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Entity                                           6468 non-null   object
#  1   Code                                             6440 non-null   object
#  2   Year                                             6468 non-null   int64
#  3   Air pollution (total) (deaths per 100,000)       6468 non-null   float64
#  4   Indoor air pollution (deaths per 100,000)        6468 non-null   float64
#  5   Outdoor particulate matter (deaths per 100,000)  6468 non-null   float64
#  6   Outdoor ozone pollution (deaths per 100,000)     6468 non-null   float64
#  7   Population                                       6468 non-null   int64
#  8   GDP                                              6468 non-null   float64
# ...
